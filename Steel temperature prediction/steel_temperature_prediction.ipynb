# %% [markdown]
# # Прогнозирование температуры стали

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Описание-этапа-обработки" data-toc-modified-id="Описание-этапа-обработки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание этапа обработки</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Установка-и-импорт-библиотек.-Подключение-к-БД" data-toc-modified-id="Установка-и-импорт-библиотек.-Подключение-к-БД-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Установка и импорт библиотек. Подключение к БД</a></span></li><li><span><a href="#Предварительный-анализ-данных" data-toc-modified-id="Предварительный-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предварительный анализ данных</a></span><ul class="toc-item"><li><span><a href="#Входной-анализ-исходных-данных" data-toc-modified-id="Входной-анализ-исходных-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Входной анализ исходных данных</a></span><ul class="toc-item"><li><span><a href="#Таблица-steel_arc" data-toc-modified-id="Таблица-steel_arc-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Таблица steel_arc</a></span></li><li><span><a href="#Таблица-steel_bulk" data-toc-modified-id="Таблица-steel_bulk-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Таблица steel_bulk</a></span></li><li><span><a href="#Таблица-steel_bulk_time" data-toc-modified-id="Таблица-steel_bulk_time-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Таблица steel_bulk_time</a></span></li><li><span><a href="#Таблица-steel_gas" data-toc-modified-id="Таблица-steel_gas-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Таблица steel_gas</a></span></li><li><span><a href="#Таблица-steel_temp" data-toc-modified-id="Таблица-steel_temp-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Таблица steel_temp</a></span></li><li><span><a href="#Таблица-steel_wire" data-toc-modified-id="Таблица-steel_wire-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Таблица steel_wire</a></span></li><li><span><a href="#Таблица-steel_wire_time" data-toc-modified-id="Таблица-steel_wire_time-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Таблица steel_wire_time</a></span></li></ul></li><li><span><a href="#Расчет-показателей" data-toc-modified-id="Расчет-показателей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Расчет показателей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Первичный-отбор-признаков" data-toc-modified-id="Первичный-отбор-признаков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Первичный отбор признаков</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span></li><li><span><a href="#Добавление-нового-столбца-и-удаление-избыточного-столбца" data-toc-modified-id="Добавление-нового-столбца-и-удаление-избыточного-столбца-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Добавление нового столбца и удаление избыточного столбца</a></span></li><li><span><a href="#Преобразование-типа-данных" data-toc-modified-id="Преобразование-типа-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Преобразование типа данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Корреляция-признаков" data-toc-modified-id="Корреляция-признаков-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Корреляция признаков</a></span></li><li><span><a href="#Исследование-данных-о-сыпучих-материалах" data-toc-modified-id="Исследование-данных-о-сыпучих-материалах-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследование данных о сыпучих материалах</a></span></li><li><span><a href="#Исследование-данных-о-проволочных-материалах###" data-toc-modified-id="Исследование-данных-о-проволочных-материалах###-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Исследование данных о проволочных материалах###</a></span></li><li><span><a href="#Исследование-данных-о-температуре" data-toc-modified-id="Исследование-данных-о-температуре-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Исследование данных о температуре</a></span></li><li><span><a href="#Исследование-числа-итераций-в-партии" data-toc-modified-id="Исследование-числа-итераций-в-партии-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Исследование числа итераций в партии</a></span></li><li><span><a href="#Исследование-продолжительности-времени-нагрева" data-toc-modified-id="Исследование-продолжительности-времени-нагрева-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Исследование продолжительности времени нагрева</a></span></li><li><span><a href="#Исследование-данных-о-полной-мощности" data-toc-modified-id="Исследование-данных-о-полной-мощности-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Исследование данных о полной мощности</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Разработка-модели-прогнозирования" data-toc-modified-id="Разработка-модели-прогнозирования-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Разработка модели прогнозирования</a></span><ul class="toc-item"><li><span><a href="#Разделение-данных-на-выборки" data-toc-modified-id="Разделение-данных-на-выборки-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Разделение данных на выборки</a></span></li><li><span><a href="#Масштабирование-количественных-признаков" data-toc-modified-id="Масштабирование-количественных-признаков-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Масштабирование количественных признаков</a></span></li><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span><ul class="toc-item"><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#GradientBoostingRegressor" data-toc-modified-id="GradientBoostingRegressor-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>GradientBoostingRegressor</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#GradientBoostingRegressor" data-toc-modified-id="GradientBoostingRegressor-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>GradientBoostingRegressor</a></span></li><li><span><a href="#Полносвязная-нейронная-сеть" data-toc-modified-id="Полносвязная-нейронная-сеть-6.4.4"><span class="toc-item-num">6.4.4&nbsp;&nbsp;</span>Полносвязная нейронная сеть</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование-и-анализ-результатов" data-toc-modified-id="Тестирование-и-анализ-результатов-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Тестирование и анализ результатов</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-модели-на-тестовой-выборке-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Проверка модели на тестовой выборке</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Для оптимизировации производственных расходов, металлургический комбинат решил уменьшить потребление электроэнергии на этапе обработки стали. Необходимо построить модель, которая будет прогнозировать температуру стали.

# %% [markdown]
# ### Описание этапа обработки

# %% [markdown]
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав, добавляя куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат.
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем сплав перемешивают и снова проводят измерения. Такой цикл повторяется до тех пор, пока не будет достигнут нужный химический состав сплава и оптимальная температура плавки.
#
# Дальше расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (англ. slab, «плита»).

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные хранятся в таблицах в базе данных PostgreSQL:
#
# `steel.data_arc` — данные об электродах,
# `steel.data_bulk` — данные о подаче сыпучих материалов (объём),
# `steel.data_bulk_time` — данные о подаче сыпучих материалов (время),
# `steel.data_gas` — данные о продувке сплава газом,
# `steel.data_temp` — результаты измерения температуры,
# `steel.data_wire` — данные о проволочных материалах (объём),
# `steel.data_wire_time` — данные о проволочных материалах (время).
#
# **1. Таблица `steel.data_arc`**
# `key` — номер партии,
# `BeginHeat` — время начала нагрева,
# `EndHeat` — время окончания нагрева,
# `ActivePower` — значение активной мощности,
# `ReactivePower` — значение реактивной мощности.
#
# **2. Таблица `steel.data_bulk`**
# `key`  — номер партии,
# `Bulk1 … Bulk15` — объём подаваемого материала.
#
# **3. Таблица `steel.data_bulk_time`**
# `key` — номер партии,
# `Bulk1 … Bulk15` — время подачи материала.
#
# **4. Таблица `steel.data_gas`**
# `key` — номер партии,
# `gas` — объём подаваемого газа.
#
# **5. Таблица `steel.data_temp`**
# `key` — номер партии,
# `MesaureTime` — время замера,
# `Temperature` — значение температуры.
#
# **6. Таблица `steel.data_wire`**
# `key` — номер партии,
# `Wire1 … Wire15` — объём подаваемых проволочных материалов.
#
# **7. Таблица `steel.data_wire_time`**
# `key` — номер партии,
# `Wire1 … Wire15` — время подачи проволочных материалов.
#
# Во всех файлах столбец key содержит номер партии. В таблицах может быть несколько строк с одинаковым значением key: они соответствуют разным итерациям обработки.

# %% [markdown]
# ## Установка и импорт библиотек. Подключение к БД

# %% [markdown]
# Установим и импортируем необходимые библиотеки:

# %%
#!pip install -q --upgrade pip

# %%
#!pip install -q skfeature-chappers optuna phik

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import optuna
import phik

import lightgbm as lgb
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from optuna.integration import OptunaSearchCV
from phik.report import plot_correlation_matrix, correlation_report
from sqlalchemy import create_engine
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import warnings
from datetime import timedelta

# %%
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

SEED=12345

# %% [markdown]
# Подключимся к БД PostgreSQL:

# %%
db_config = {
'user': , # имя пользователя,
'pwd': , # пароль,
'host': , # хост
'port': , # порт подключения,
'db': # название базы данных,
}

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %% [markdown]
# ## Предварительный анализ данных

# %% [markdown]
# Сохраним таблицы из БД в виде датафреймов:

# %%
# данные об электродах
query_steel_data_arc = '''
SELECT *
FROM steel.data_arc;
'''
steel_arc = pd.read_sql_query(query_steel_data_arc, con=engine)

# данные о подаче сыпучих материалов(объем)
query_steel_data_bulk = '''
SELECT *
FROM steel.data_bulk;
'''
steel_bulk = pd.read_sql_query(query_steel_data_bulk, con=engine)

# данные о подаче сыпучих материалов(время)
query_steel_data_bulk_time = '''
SELECT *
FROM steel.data_bulk_time;
'''
steel_bulk_time = pd.read_sql_query(query_steel_data_bulk_time, con=engine)

# данные о продувке сплава газом
query_steel_data_gas = '''
SELECT *
FROM steel.data_gas;
'''
steel_gas = pd.read_sql_query(query_steel_data_gas, con=engine)


# результаты измерения температуры
query_steel_data_temp = '''
SELECT *
FROM steel.data_temp;
'''
steel_temp = pd.read_sql_query(query_steel_data_temp, con=engine)


# данные о проволочных материалах(объём)
query_steel_data_wire = '''
SELECT *
FROM steel.data_wire;
'''
steel_wire = pd.read_sql_query(query_steel_data_wire, con=engine)

# данные о проволочных материалах(время)
query_steel_data_wire_time = '''
SELECT *
FROM steel.data_wire_time;
'''
steel_wire_time = pd.read_sql_query(query_steel_data_wire_time, con=engine)

# %% [markdown]
# ### Входной анализ исходных данных

# %% [markdown]
# Для анализа выведем информацию о каждой таблице, используя следующую функцию:

# %%
def func_info(df):
  print('1. Размер выборки:\n', df.shape)
  print('\n2. 5 случайных строк DataFrame:')
  display(df.sample(5))
  print('3. Количество партий:', len(df['key'].unique()))
  print('\n4. Краткая сводка DataFrame:')
  print(df.info())
  print('\n5. Описательная статистика DataFrame:')
  display(df.describe())

# %% [markdown]
# #### Таблица steel_arc

# %%
func_info(steel_arc)
# Out:
# 1. Размер выборки:
#  (14876, 5)
#
# 2. 5 случайных строк DataFrame:
#         key BeginHeat   EndHeat  ActivePower  ReactivePower
# 10898  2371  15:42:12  15:45:27     0.770267       0.576580
# 3592    780  08:49:53  08:52:35     0.539198       0.349899
# 13496  2930  18:59:47  19:01:24     0.357858       0.252157
# 245      52  06:39:55  06:42:31     0.540310       0.376993
# 13796  2993  01:03:51  01:05:53     0.400342       0.334771
# 3. Количество партий: 3214
#
# 4. Краткая сводка DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   key            14876 non-null  int64
#  1   BeginHeat      14876 non-null  object
#  2   EndHeat        14876 non-null  object
#  3   ActivePower    14876 non-null  float64
#  4   ReactivePower  14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# ...

# %% [markdown]
# #### Таблица steel_bulk

# %%
func_info(steel_bulk)
# Out:
# 1. Размер выборки:
#  (3129, 16)
#
# 2. 5 случайных строк DataFrame:
#        key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 2979  3088     NaN     NaN   138.0     NaN     NaN     NaN     NaN     NaN
# 1757  1819     NaN     NaN   132.0     NaN     NaN     NaN     NaN     NaN
# 395    421     NaN     NaN    93.0     NaN     NaN     NaN     NaN     NaN
# 2714  2815     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1229  1279     NaN     NaN    92.0     NaN     NaN     NaN     NaN     NaN
#
#       Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 2979     NaN      NaN      NaN    158.0      NaN    150.0      NaN
# 1757     NaN      NaN      NaN    206.0      NaN     99.0    206.0
# 395      NaN      NaN      NaN    221.0      NaN    124.0    223.0
# 2714     NaN      NaN      NaN    412.0      NaN    100.0      NaN
# 1229     NaN    106.0      NaN    412.0      NaN    222.0    208.0
# 3. Количество партий: 3129
#
# ...

# %% [markdown]
# #### Таблица steel_bulk_time

# %%
func_info(steel_bulk_time)
# Out:
# 1. Размер выборки:
#  (3129, 16)
#
# 2. 5 случайных строк DataFrame:
#        key Bulk 1 Bulk 2    Bulk 3    Bulk 4 Bulk 5    Bulk 6 Bulk 7 Bulk 8  \
# 1962  2029   None   None  20:43:44      None   None  20:30:34   None   None
# 2128  2201   None   None  16:16:03      None   None      None   None   None
# 981   1025   None   None  23:36:06      None   None  23:36:06   None   None
# 1764  1824   None   None  05:51:39      None   None      None   None   None
# 2154  2230   None   None      None  15:51:33   None      None   None   None
#
#      Bulk 9 Bulk 10   Bulk 11   Bulk 12 Bulk 13   Bulk 14   Bulk 15
# 1962   None    None  20:30:34  20:14:28    None  20:14:28  20:14:28
# 2128   None    None      None  16:06:03    None  16:06:03  16:06:03
# 981    None    None      None      None    None      None      None
# 1764   None    None      None      None    None  05:43:16      None
# 2154   None    None      None  15:44:41    None  15:28:47  15:44:41
# 3. Количество партий: 3129
#
# ...

# %% [markdown]
# #### Таблица steel_gas

# %%
func_info(steel_gas)
# Out:
# 1. Размер выборки:
#  (3239, 2)
#
# 2. 5 случайных строк DataFrame:
#        key        gas
# 593    596   6.709936
# 2127  2130   9.991967
# 50      51   9.236758
# 2356  2359  27.355651
# 546    549  15.931603
# 3. Количество партий: 3239
#
# 4. Краткая сводка DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   gas     3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
# None
#
# 5. Описательная статистика DataFrame:
#                key          gas
# count  3239.000000  3239.000000
# mean   1621.861377    11.002062
# std     935.386334     6.220327
# min       1.000000     0.008399
# 25%     812.500000     7.043089
# 50%    1622.000000     9.836267
# 75%    2431.500000    13.769915
# max    3241.000000    77.995040

# %% [markdown]
# #### Таблица steel_temp

# %%
func_info(steel_temp)
# Out:
# 1. Размер выборки:
#  (15907, 3)
#
# 2. 5 случайных строк DataFrame:
#         key MesaureTime  Temperature
# 14721  2984    17:38:35          NaN
# 13577  2762    14:31:35          NaN
# 4851    969    01:13:43       1575.0
# 3145    620    04:14:12       1581.0
# 15304  3109    21:09:22          NaN
# 3. Количество партий: 3216
#
# 4. Краткая сводка DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key          15907 non-null  int64
#  1   MesaureTime  15907 non-null  object
#  2   Temperature  13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB
# None
#
# 5. Описательная статистика DataFrame:
#                 key   Temperature
# count  15907.000000  13006.000000
# mean    1607.880870   1591.840920
# std      942.212073     21.375851
# min        1.000000   1191.000000
# ...

# %% [markdown]
# #### Таблица steel_wire

# %%
func_info(steel_wire)
# Out:
# 1. Размер выборки:
#  (3081, 10)
#
# 2. 5 случайных строк DataFrame:
#        key      Wire 1  Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  \
# 2311  2435   57.089764     NaN     NaN     NaN     NaN     NaN     NaN
# 2232  2343  105.137757     NaN     NaN     NaN     NaN     NaN     NaN
# 1697  1784   68.047203     NaN     NaN     NaN     NaN     NaN     NaN
# 1174  1242  105.253201     NaN     NaN     NaN     NaN     NaN     NaN
# 2915  3074  143.095673   15.08     NaN     NaN     NaN     NaN     NaN
#
#       Wire 8  Wire 9
# 2311     NaN     NaN
# 2232     NaN     NaN
# 1697     NaN     NaN
# 1174     NaN     NaN
# 2915     NaN     NaN
# 3. Количество партий: 3081
#
# 4. Краткая сводка DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
# ...

# %% [markdown]
# #### Таблица steel_wire_time

# %%
func_info(steel_wire_time)
# Out:
# 1. Размер выборки:
#  (3081, 10)
#
# 2. 5 случайных строк DataFrame:
#        key    Wire 1    Wire 2    Wire 3 Wire 4 Wire 5 Wire 6 Wire 7 Wire 8  \
# 607    643  23:21:24      None      None   None   None   None   None   None
# 1045  1111  21:06:46  21:08:18  21:27:01   None   None   None   None   None
# 433    465  15:15:20  15:17:51      None   None   None   None   None   None
# 2480  2607  22:33:35      None      None   None   None   None   None   None
# 1895  1989  08:11:53      None      None   None   None   None   None   None
#
#      Wire 9
# 607    None
# 1045   None
# 433    None
# 2480   None
# 1895   None
# 3. Количество партий: 3081
#
# 4. Краткая сводка DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
# ...

# %% [markdown]
# ### Расчет показателей

# %% [markdown]
# Рассчитаем дельту времени между первым и последним замером температуры:

# %%
steel_temp['MesaureTime'] = pd.to_timedelta(steel_temp['MesaureTime'].astype(str))
grouped_temp = steel_temp.groupby(by='key', axis=0)
grouped_temp = grouped_temp['MesaureTime'].agg(first_time='first', last_time='last')

# %% [markdown]
# Есть партии, в которых время первого и последнего замеры температуры происходили в разные дни:

# %%
grouped_temp.query('first_time > last_time').head()
# Out:
#          first_time       last_time
# key
# 18  0 days 23:22:18 0 days 00:08:29
# 44  0 days 22:13:44 0 days 01:13:17
# 45  0 days 23:06:36 0 days 00:26:13
# 46  0 days 23:54:43 0 days 03:14:53
# 74  0 days 23:51:01 0 days 00:19:42

# %%
excluded_keys = grouped_temp.query('first_time > last_time').index.tolist()
len(excluded_keys)
# Out:
# 71

# %% [markdown]
# Таких партий оказалось 71, учтем это при расчете дельты между первым и последним замером температуры.

# %%
def func_diff_time(row):
    if row['first_time'] > row['last_time']:
        return timedelta(hours=24) - row['first_time'] + row['last_time']
    else:
        return row['last_time'] - row['first_time']

# %%
grouped_temp['diff_time'] = grouped_temp.apply(func_diff_time, axis=1)
grouped_temp.sample(5)
# Out:
#           first_time       last_time       diff_time
# key
# 2309 0 days 07:57:50 0 days 08:15:55 0 days 00:18:05
# 75   0 days 00:36:57 0 days 01:06:47 0 days 00:29:50
# 249  0 days 13:45:23 0 days 14:15:26 0 days 00:30:03
# 1071 0 days 15:14:30 0 days 15:30:48 0 days 00:16:18
# 996  0 days 22:10:08 0 days 22:36:36 0 days 00:26:28

# %% [markdown]
# Проверим, есть ли партии, в которых время первого и последнего замера температуры равны:

# %%
grouped_temp.query('first_time == last_time')
# Out:
#          first_time       last_time diff_time
# key
# 195 0 days 14:10:23 0 days 14:10:23    0 days
# 279 0 days 23:07:28 0 days 23:07:28    0 days

# %% [markdown]
# Таких партий оказалось 2 - не будем их учитывать.

# %% [markdown]
# Рассчитаем статистические показатели:

# %%
grouped_temp.query('first_time != last_time').describe()
# Out:
#                       first_time                  last_time  \
# count                       3214                       3214
# mean   0 days 11:50:27.587118855  0 days 11:49:19.943995021
# std    0 days 06:55:32.164183026  0 days 06:55:34.858687094
# min              0 days 00:00:14            0 days 00:00:27
# 25%              0 days 05:53:07            0 days 05:54:04
# 50%              0 days 11:39:41            0 days 11:37:30
# 75%       0 days 17:48:09.750000     0 days 17:44:29.250000
# max              0 days 23:59:39            0 days 23:59:54
#
#                        diff_time
# count                       3214
# mean   0 days 00:30:41.006533914
# std    0 days 00:20:46.492873846
# min              0 days 00:03:17
# 25%       0 days 00:19:38.250000
# 50%              0 days 00:26:23
# 75%              0 days 00:37:15
# max              0 days 06:32:17

# %% [markdown]
# Как видно из полученной таблицы:
# - в среднем дельта между первым и последним замером температуры стали составляет около 30 минут;
# - минимальная дельта - 3 минуты 17 секунд;
# - максимальная дельта - 6 часов 32 минуты.

# %% [markdown]
# Далее рассчитаем:
# - суммарное время нагрева электродами;
# - количество запусков нагрева электродами;
# - среднее соотношение потребления активной и реактивной мощности.

# %% [markdown]
# Сначала рассчитаем дельту времени между запусками электродов:

# %%
steel_arc['BeginHeat'] = pd.to_timedelta(steel_arc['BeginHeat'].astype(str))
steel_arc['EndHeat'] = pd.to_timedelta(steel_arc['EndHeat'].astype(str))

# %% [markdown]
# Для этих данных также есть партии, в которых время первого и последнего нагрева происходили в разные дни, учтем это:

# %%
def func_diff_time_arc(row):
    if row['BeginHeat'] > row['EndHeat']:
        return timedelta(hours=24) - row['BeginHeat'] + row['EndHeat']
    else:
        return row['EndHeat'] - row['BeginHeat']

# %%
steel_arc['diff_time_arc'] = steel_arc.apply(func_diff_time_arc, axis=1)
steel_arc.sample(5)
# Out:
#         key       BeginHeat         EndHeat  ActivePower  ReactivePower  \
# 8019   1738 0 days 01:28:13 0 days 01:29:36     0.362945       0.237222
# 4953   1068 0 days 13:17:27 0 days 13:19:28     0.474155       0.386985
# 12762  2771 0 days 01:30:17 0 days 01:32:17     0.524268       0.318877
# 13988  3037 0 days 14:11:22 0 days 14:15:53     1.238065       0.878981
# 14507  3156 0 days 06:15:57 0 days 06:18:01     0.433580       0.336577
#
#         diff_time_arc
# 8019  0 days 00:01:23
# 4953  0 days 00:02:01
# 12762 0 days 00:02:00
# 13988 0 days 00:04:31
# 14507 0 days 00:02:04

# %% [markdown]
# Рассчитаем суммарное время и количество запусков нагрева электродами :

# %%
grouped_arc = steel_arc.groupby(by='key', axis=0)['diff_time_arc'].agg(total_time='sum', count_arc='count')
grouped_arc.describe()
# Out:
#                       total_time    count_arc
# count                       3214  3214.000000
# mean   0 days 00:13:14.579029247     4.628500
# std    0 days 00:05:32.448622113     1.608647
# min              0 days 00:00:57     1.000000
# 25%              0 days 00:09:31     4.000000
# 50%              0 days 00:12:50     4.000000
# 75%              0 days 00:16:23     6.000000
# max              0 days 01:09:49    16.000000

# %% [markdown]
# Далее - среднее соотношение потребления активной и реактивной мощности:

# %%
steel_arc['ratio_power'] = steel_arc['ActivePower'] / steel_arc['ReactivePower']
mean_ratio_power = steel_arc.groupby(by='key', axis=0)['ratio_power'].mean()
mean_ratio_power.describe()
# Out:
# count    3214.000000
# mean        1.357452
# std         0.132824
# min         0.676106
# 25%         1.292892
# 50%         1.370550
# 75%         1.438292
# max         1.782164
# Name: ratio_power, dtype: float64

# %% [markdown]
# Как видно из полученноых данных:
# - среднее время нагрева электродами составляет 13 минут;
# - минимальное время - 57 секунд;
# - максимальное - 1 час 10 минут;
# - в одной партии встречается от 1 до 16 итераций, среднее количество итераций нагрева - 5.
#
# Также рассчитали среднее соотношение потребления активной и реактивной мощности.

# %% [markdown]
# ### Вывод

# %% [markdown]
# По результатам предварительного анализа данных можно сделать следующий вывод:
# - количество таблиц соответствует условию задачи;
# - все таблицы имеет общий ключ key - номер партии, при этом количество уникальных партий в каждой таблице разное;
# - в таблицах с данными о проволочных и сыпучих материалах присутствует большое количество пропусков - это скорее всего связано с тем, что добавки использовались не на каждой итерации технологического процесса изготовления стали.
#
# Также в рамках данного раздела были рассчитаны суммарное время нагрева электродами, количество запусков нагрева электродами и среднее соотношение потребления активной и реактивной мощности.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Первичный отбор признаков

# %% [markdown]
# Проведем первичный отбор признаков, необходимых для обучения модели предсказания, и агрегируем их:

# %%
query = f'''
WITH a AS
(SELECT key, 
        count(*) AS count_iteration,
        SUM(CASE
            WHEN "BeginHeat" > "EndHeat" THEN INTERVAL '24 hour' - "BeginHeat"::INTERVAL + "EndHeat"::INTERVAL
            ELSE "EndHeat" - "BeginHeat"
            END
        ) AS arc_total_time,
        ROUND(SUM(SQRT(POWER("ActivePower", 2) + POWER("ReactivePower", 2))), 2) AS total_power
FROM steel.data_arc
GROUP BY key
ORDER BY key),

b AS (SELECT key, 
             SUM("Bulk 1") AS volume_bulk_1, SUM("Bulk 2") AS volume_bulk_2, SUM("Bulk 3") AS volume_bulk_3,
             SUM("Bulk 4") AS volume_bulk_4, SUM("Bulk 5") AS volume_bulk_5, SUM("Bulk 6") AS volume_bulk_6,
             SUM("Bulk 7") AS volume_bulk_7, SUM("Bulk 8") AS volume_bulk_8, SUM("Bulk 9") AS volume_bulk_9,
             SUM("Bulk 10") AS volume_bulk_10, SUM("Bulk 11") AS volume_bulk_11, SUM("Bulk 12") AS volume_bulk_12,
             SUM("Bulk 13") AS volume_bulk_13, SUM("Bulk 14") AS volume_bulk_14, SUM("Bulk 15") AS volume_bulk_15
      FROM steel.data_bulk
      GROUP BY key
      ORDER BY key),

g AS (SELECT key, ROUND(SUM("gas"), 4) AS volume_gas
      FROM steel.data_gas
      GROUP BY key
      ORDER BY key),

t AS (SELECT DISTINCT key,
        LAST_VALUE("Temperature") OVER(PARTITION BY key ORDER BY "MesaureTime" 
        RANGE BETWEEN CURRENT ROW AND UNBOUNDED FOLLOWING) AS temperature,
        FIRST_VALUE("Temperature") OVER(PARTITION BY key ORDER BY "MesaureTime") AS first_temperature
        FROM steel.data_temp
        WHERE key not in %(excluded_keys)s
        ORDER BY key),

w AS (SELECT key,
            SUM("Wire 1") AS volume_wire_1, SUM("Wire 2") AS volume_wire_2, SUM("Wire 3") AS volume_wire_3,
            SUM("Wire 4") AS volume_wire_4, SUM("Wire 5") AS volume_wire_5, SUM("Wire 6") AS volume_wire_6,
            SUM("Wire 7") AS volume_wire_7, SUM("Wire 8") AS volume_wire_8, SUM("Wire 9") AS volume_wire_9
FROM steel.data_wire
GROUP BY key
ORDER BY key)


SELECT *
FROM a
INNER JOIN b ON b.key = a.key
INNER JOIN g ON g.key = b.key
INNER JOIN t ON t.key = g.key
INNER JOIN w ON w.key = t.key
'''

# %% [markdown]
# Полученный датафрейм сохраним в новой переменной, удалив задублированные столбцы:

# %%
df_steel = pd.read_sql_query(query, params={'excluded_keys': tuple(excluded_keys)}, con=engine)
df_steel = df_steel.loc[:, ~df_steel.columns.duplicated()]
df_steel.sample(5)
# Out:
#        key  count_iteration  arc_total_time  total_power  volume_bulk_1  \
# 1374  1507                6 0 days 00:09:35         2.67            NaN
# 2339  2565                7 0 days 00:12:16         3.44           44.0
# 2927  3218                3 0 days 00:14:14         4.07            NaN
# 1948  2129                4 0 days 00:10:39         3.06            NaN
# 836    928                5 0 days 00:18:24         5.80            NaN
#
#       volume_bulk_2  volume_bulk_3  volume_bulk_4  volume_bulk_5  \
# 1374            NaN            NaN            NaN            NaN
# 2339          254.0            NaN          100.0          136.0
# 2927            NaN            NaN            NaN            NaN
# 1948            NaN           67.0            NaN            NaN
# 836             NaN          154.0            NaN            NaN
#
#       volume_bulk_6  volume_bulk_7  volume_bulk_8  volume_bulk_9  \
# 1374           45.0            NaN            NaN            NaN
# ...

# %% [markdown]
# Выведем информацию о датафрейме:

# %%
func_info(df_steel)
# Out:
# 1. Размер выборки:
#  (2951, 31)
#
# 2. 5 случайных строк DataFrame:
#        key  count_iteration  arc_total_time  total_power  volume_bulk_1  \
# 1974  2156                4 0 days 00:10:45         3.38            NaN
# 1516  1665                3 0 days 00:12:11         3.79            NaN
# 304    353                6 0 days 00:18:29         5.77            NaN
# 1532  1682                4 0 days 00:08:20         1.94            NaN
# 603    670                5 0 days 00:15:37         3.87            NaN
#
#       volume_bulk_2  volume_bulk_3  volume_bulk_4  volume_bulk_5  \
# 1974            NaN            NaN            NaN            NaN
# 1516            NaN          114.0           45.0            NaN
# 304             NaN            NaN            NaN            NaN
# 1532            NaN           22.0            NaN            NaN
# 603             NaN            NaN          281.0            NaN
#
#       volume_bulk_6  volume_bulk_7  volume_bulk_8  volume_bulk_9  \
# ...

# %% [markdown]
# ### Обработка пропущенных значений

# %% [markdown]
# Рассчитаем количество пропусков:

# %%
df_steel.isna().sum()
# Out:
# key                     0
# count_iteration         0
# arc_total_time          0
# total_power             0
# volume_bulk_1        2706
# volume_bulk_2        2929
# volume_bulk_3        1686
# volume_bulk_4        1963
# volume_bulk_5        2878
# volume_bulk_6        2397
# volume_bulk_7        2927
# volume_bulk_8        2950
# volume_bulk_9        2933
# volume_bulk_10       2776
# volume_bulk_11       2778
# volume_bulk_12        656
# volume_bulk_13       2936
# volume_bulk_14        308
# volume_bulk_15        772
# volume_gas              0
# temperature           676
# first_temperature       0
# volume_wire_1          25
# volume_wire_2        1919
# volume_wire_3        2889
# volume_wire_4        2937
# volume_wire_5        2950
# volume_wire_6        2880
# volume_wire_7        2940
# volume_wire_8        2933
# volume_wire_9        2927
# dtype: int64

# %% [markdown]
# В столбце temperature 676 пропусков. Поскольку это целевой признак, удалим строки с пропусками из датасета:

# %%
df_steel = df_steel.dropna(subset=['temperature'])

# %%
print(df_steel.shape)
df_steel.isna().sum()
# Out:
# (2275, 31)
# key                     0
# count_iteration         0
# arc_total_time          0
# total_power             0
# volume_bulk_1        2081
# volume_bulk_2        2262
# volume_bulk_3        1335
# volume_bulk_4        1479
# volume_bulk_5        2226
# volume_bulk_6        1851
# volume_bulk_7        2262
# volume_bulk_8        2274
# volume_bulk_9        2263
# volume_bulk_10       2133
# volume_bulk_11       2147
# volume_bulk_12        509
# volume_bulk_13       2264
# volume_bulk_14        257
# volume_bulk_15        617
# volume_gas              0
# temperature             0
# first_temperature       0
# volume_wire_1          23
# volume_wire_2        1481
# volume_wire_3        2237
# volume_wire_4        2263
# volume_wire_5        2275
# volume_wire_6        2230
# volume_wire_7        2271
# volume_wire_8        2263
# volume_wire_9        2252
# dtype: int64

# %% [markdown]
# В столбце volume_wire_5 нет данных, в volume_bulk_8 - присутствует только одна запись. Удалим эти столбцы из датасета:

# %%
df_steel = df_steel.drop(columns=['volume_wire_5', 'volume_bulk_8'])

# %%
df_steel.shape
# Out:
# (2275, 29)

# %% [markdown]
# В остальных столбцах пропущенные значения значают, что в некоторых данных партиях не добавляли те или иные материалы, заполним данные пропуски нулями:

# %%
col_bulk = [f'volume_bulk_{i}' for i in range(1, 16) if i != 8]
col_wire = [f'volume_wire_{i}' for i in range(1, 10) if i != 5]
columns_null = col_bulk + col_wire

# %%
df_steel[columns_null] = df_steel[columns_null].fillna(0)
df_steel.sample(5)
# Out:
#        key  count_iteration  arc_total_time  total_power  volume_bulk_1  \
# 2179  2394                3 0 days 00:11:44         3.26            0.0
# 1553  1704                2 0 days 00:08:02         2.58            0.0
# 686    765                2 0 days 00:03:44         1.08            0.0
# 959   1067                4 0 days 00:06:34         1.91            0.0
# 1519  1668                7 0 days 00:18:37         6.07            0.0
#
#       volume_bulk_2  volume_bulk_3  volume_bulk_4  volume_bulk_5  \
# 2179            0.0            0.0           65.0            0.0
# 1553            0.0            0.0          128.0            0.0
# 686             0.0            0.0           71.0            0.0
# 959             0.0          163.0            0.0            0.0
# 1519            0.0            0.0            0.0           23.0
#
#       volume_bulk_6  volume_bulk_7  volume_bulk_9  volume_bulk_10  \
# 2179            0.0            0.0            0.0             0.0
# ...

# %% [markdown]
# Как видно, пропуски заполнены.

# %% [markdown]
# ### Добавление нового столбца и удаление избыточного столбца

# %% [markdown]
# Добавлим новый столбец с продолжительностью нагрева в минутах

# %%
df_steel['arc_minutes'] = round(df_steel['arc_total_time'].dt.total_seconds() / 60, 4)
df_steel.sample(5)
# Out:
#        key  count_iteration  arc_total_time  total_power  volume_bulk_1  \
# 1111  1232                3 0 days 00:05:10         1.39            0.0
# 992   1101                6 0 days 00:14:44         4.65            0.0
# 1102  1223                6 0 days 00:15:30         4.47            0.0
# 457    516                2 0 days 00:06:13         1.94            0.0
# 150    177                6 0 days 00:16:31         4.45            0.0
#
#       volume_bulk_2  volume_bulk_3  volume_bulk_4  volume_bulk_5  \
# 1111            0.0            0.0           90.0            0.0
# 992             0.0          354.0            0.0            0.0
# 1102            0.0            0.0            0.0            0.0
# 457             0.0            0.0          123.0            0.0
# 150             0.0            0.0          140.0            0.0
#
#       volume_bulk_6  volume_bulk_7  volume_bulk_9  volume_bulk_10  \
# 1111            0.0            0.0            0.0             0.0
# ...

# %% [markdown]
# Удалим избыточный столбец:

# %%
df_steel = df_steel.drop(['arc_total_time', 'key'], axis=1)
df_steel.sample(5)
# Out:
#      count_iteration  total_power  volume_bulk_1  volume_bulk_2  \
# 934                9         8.39            0.0            0.0
# 635                3         1.49            0.0            0.0
# 533                4         2.05            0.0            0.0
# 233                3         2.99            0.0            0.0
# 212                2         1.33            0.0            0.0
#
#      volume_bulk_3  volume_bulk_4  volume_bulk_5  volume_bulk_6  \
# 934           98.0            0.0            0.0            0.0
# 635            0.0          112.0            0.0            0.0
# 533            0.0          158.0            0.0            0.0
# 233           42.0            0.0            0.0          167.0
# 212            0.0           62.0            0.0            0.0
#
#      volume_bulk_7  volume_bulk_9  volume_bulk_10  volume_bulk_11  \
# 934            0.0            0.0             0.0             0.0
# ...

# %% [markdown]
# ### Преобразование типа данных

# %% [markdown]
# Преобразуем типы данных в следующих столбцах:

# %%
df_steel[columns_null] = df_steel[columns_null].astype('int')
df_steel['temperature'] = df_steel['temperature'].astype('int')
df_steel['first_temperature'] = df_steel['first_temperature'].astype('int')
df_steel.dtypes
# Out:
# count_iteration        int64
# total_power          float64
# volume_bulk_1          int64
# volume_bulk_2          int64
# volume_bulk_3          int64
# volume_bulk_4          int64
# volume_bulk_5          int64
# volume_bulk_6          int64
# volume_bulk_7          int64
# volume_bulk_9          int64
# volume_bulk_10         int64
# volume_bulk_11         int64
# volume_bulk_12         int64
# volume_bulk_13         int64
# volume_bulk_14         int64
# volume_bulk_15         int64
# volume_gas           float64
# temperature            int64
# first_temperature      int64
# volume_wire_1          int64
# volume_wire_2          int64
# volume_wire_3          int64
# volume_wire_4          int64
# volume_wire_6          int64
# volume_wire_7          int64
# volume_wire_8          int64
# volume_wire_9          int64
# arc_minutes          float64
# dtype: object

# %% [markdown]
# Типы данных изменены.

# %% [markdown]
# ### Вывод

# %% [markdown]
# В рамках этапа предобработки данных были проведены следующие мероприятия:
# - проведен отбор признаков,
# - заполнены пропущенные значения в данных,
# - измененены типы данных,
# - добавлен новый столбце и удален избыточный.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Корреляция признаков

# %% [markdown]
# Посмотрим на линейную корреляцию признаков:

# %%
corr_matrix = df_steel.corr()
plot_correlation_matrix(corr_matrix.values, 
                        x_labels=corr_matrix.columns, 
                        y_labels=corr_matrix.index, 
                        color_map="seismic", 
                        title="Линейная корреляция признаков", 
                        fontsize_factor=1, 
                        figsize=(15, 12))
plt.tight_layout()

# %% [markdown]
# Как видно из полученной визуализации:
# - в основном преобладает прямая линейная зависимость признаков;
# - пара признаков volume_wire_8 и volume_bulk_9 сильно коррелируются между собой (коэффициент корреляции 0.97) - удалим один признак из датасета;
# - время нагрева и количество итераций в партии имеют высокую прямую линейную зависимость.

# %%
df_steel = df_steel.drop(columns=['volume_wire_8'])
col_wire.remove('volume_wire_8')

# %% [markdown]
# Построим  матрицу Фи-коэффициентов для анализа нелинейных зависимостей:

# %%
phik_matrix = df_steel.phik_matrix()
# Out:
# interval columns not set, guessing: ['count_iteration', 'total_power', 'volume_bulk_1', 'volume_bulk_2', 'volume_bulk_3', 'volume_bulk_4', 'volume_bulk_5', 'volume_bulk_6', 'volume_bulk_7', 'volume_bulk_9', 'volume_bulk_10', 'volume_bulk_11', 'volume_bulk_12', 'volume_bulk_13', 'volume_bulk_14', 'volume_bulk_15', 'volume_gas', 'temperature', 'first_temperature', 'volume_wire_1', 'volume_wire_2', 'volume_wire_3', 'volume_wire_4', 'volume_wire_6', 'volume_wire_7', 'volume_wire_9', 'arc_minutes']

# %%
plot_correlation_matrix(phik_matrix.values, 
                        x_labels=phik_matrix.columns, 
                        y_labels=phik_matrix.index, 
                        color_map="seismic", 
                        title=r"Корреляция $\phi_K$", 
                        fontsize_factor=1, 
                        figsize=(15, 12))
plt.tight_layout()

# %% [markdown]
# Как видно из полученной визуализации:
# - по сравнению с линейной корреляцией, прослеживаются более сильные нелинейные зависимости признаков, например, взаимосвязь между различными проволочными и сыпучими материалами;
# - также присутствует сильная зависимость между полной мощностью и временем нагрева сплава.

# %% [markdown]
# ### Исследование данных о сыпучих материалах

# %% [markdown]
# Отобразим долю использования сыпучих материалов в партиях и сравним, какие из них используются менее чем в 5% партий:

# %%
plt.figure(figsize = (10,6))
ax = df_steel[col_bulk].where(df_steel[col_bulk] == 0, 1).mean().sort_values(ascending=False).plot(
    kind = 'bar', grid=True, color='grey'
)
ax.axhline(y=0.05, color='r', linestyle='-')
ax.set_title('Частота применения сыпучих материалов')
ax.set_ylabel('Доля использования')
ax.set_xlabel('Тип сыпучего материала')
None

# %% [markdown]
# Как видно из визуализации, почти треть сыпучих материалов использовалась менее чем в 5-ти процентах партий.

# %% [markdown]
# ### Исследование данных о проволочных материалах###

# %% [markdown]
# Исследуем частоту добавления проволочных материалов в каждую партию:

# %%
plt.figure(figsize = (10,6))
ax = df_steel[col_wire].where(df_steel[col_wire] == 0, 1).mean().sort_values(ascending=False).plot(
    kind = 'bar', grid=True, color='grey'
)
ax.axhline(y=0.05, color='r', linestyle='-')
ax.set_title('Частота применения проволочных материалов')
ax.set_ylabel('Доля использования')
ax.set_xlabel('Тип проволочного материала')
None

# %% [markdown]
# Как видно из визуализации, первый проволочный материал применялся практически в каждой партии.

# %% [markdown]
# ### Исследование данных о температуре

# %%
df_steel['temperature'].hist(range=(1500, 1700), figsize=(10,6), color='grey')
plt.xlabel('Температура')
plt.ylabel('Частота')
plt.title('Распределения данных о температуре')
None

# %% [markdown]
# Видны некоторые аномальные значения:

# %%
df_steel.query('temperature < 1545 or temperature > 1650')['temperature'].count()
# Out:
# 3

# %% [markdown]
# Удалим эти строки:

# %%
df_steel = df_steel.query('temperature >= 1545 and temperature <= 1650').reset_index(drop=True)

# %% [markdown]
# ### Исследование числа итераций в партии

# %%
df_steel['count_iteration'].hist(range=(0, 20), figsize=(10,6), color='grey')
plt.xlabel('Число итераций в партии')
plt.ylabel('Частота')
plt.title('Распределение числа итераций в партии')
None

# %% [markdown]
# Видны некоторые аномальные значения:

# %%
df_steel.query('count_iteration > 13')['count_iteration'].count()
# Out:
# 2

# %% [markdown]
# Удалим эти строки:

# %%
df_steel = df_steel.query('count_iteration <= 13').reset_index(drop=True)

# %% [markdown]
# ### Исследование продолжительности времени нагрева

# %%
df_steel['arc_minutes'].hist(range=(0, 50), figsize=(10,6), color='grey')
plt.xlabel('Время нагрева стали')
plt.ylabel('Частота')
plt.title('Распределение продолжительности времени нагрева стали')
None

# %% [markdown]
# Видны некоторые аномальные значения:

# %%
df_steel.query('arc_minutes > 35')['arc_minutes'].count()
# Out:
# 3

# %% [markdown]
# Удалим эти строки:

# %%
df_steel = df_steel.query('arc_minutes <= 35').reset_index(drop=True)

# %% [markdown]
# ### Исследование данных о полной мощности

# %%
df_steel['total_power'].hist(range=(0, 15), figsize=(10,6), color='grey')
plt.xlabel('Полная мощность')
plt.ylabel('Частота')
plt.title('Распределение полной мощности')
None

# %% [markdown]
# Видны некоторые аномальные значения:

# %%
df_steel.query('total_power > 10')['total_power'].count()
# Out:
# 5

# %% [markdown]
# Удалим эти строки:

# %%
df_steel = df_steel.query('total_power <= 10').reset_index(drop=True)

# %% [markdown]
# ### Вывод

# %% [markdown]
# В рамках данного этапа были проанализированы:
# - линейная и нелинейная корреляция признаков,
# - доля использования сыпучих материалов в партиях,
# - частота добавления проволочных материалов,
# - распределение данных о температуре,
# - распределение числа итераций в партии,
# - распределение продолжительности времени нагрева стали,
# - распределение полной мощности.

# %% [markdown]
# ## Разработка модели прогнозирования

# %% [markdown]
# ### Разделение данных на выборки

# %% [markdown]
# Выделим признаки и целевой признак в отдельные переменные:

# %%
features = df_steel.drop(['temperature'], axis=1)
target = df_steel['temperature']

# %% [markdown]
# Разделим выборки на обучающую и тестовую:

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, shuffle=True, random_state=SEED
)

# %% [markdown]
# Размеры получившихся выборок:

# %%
print(features_train.shape)
print(target_train.shape)
print(features_test.shape)
print(target_test.shape)
# Out:
# (1696, 26)
# (1696,)
# (566, 26)
# (566,)

# %% [markdown]
# ### Масштабирование количественных признаков

# %% [markdown]
# Отмасштабируем количественные признаки с помощью MinMaxScaler:

# %%
scaler = MinMaxScaler(feature_range = (0,1))

scaler.fit(features_train)
features_train_scaler = scaler.transform(features_train)
features_test_scaler = scaler.transform(features_test)

# %%
features_train = pd.DataFrame(
    features_train_scaler, 
    columns=features_train.columns,
    index=features_train.index
)

features_train.sample(5)
# Out:
#       count_iteration  total_power  volume_bulk_1  volume_bulk_2  \
# 2215         0.222222     0.274793            0.0            0.0
# 1140         0.888889     0.668388            0.0            0.0
# 972          0.222222     0.260331            0.0            0.0
# 31           0.666667     0.661157            0.0            0.0
# 176          0.444444     0.210744            0.0            0.0
#
#       volume_bulk_3  volume_bulk_4  volume_bulk_5  volume_bulk_6  \
# 2215       0.000000       0.000000            0.0            0.0
# 1140       0.359031       0.000000            0.0            1.0
# 972        0.290749       0.000000            0.0            0.0
# 31         0.096916       0.412811            0.0            0.0
# 176        0.000000       0.373665            0.0            0.0
#
#       volume_bulk_7  volume_bulk_9  volume_bulk_10  volume_bulk_11  \
# 2215            0.0            0.0             0.0             0.0
# ...

# %%
features_test = pd.DataFrame(
    features_test_scaler, 
    columns=features_test.columns,
    index=features_test.index
)
features_test.sample(5)
# Out:
#       count_iteration  total_power  volume_bulk_1  volume_bulk_2  \
# 2253         0.444444     0.512397            0.0            0.0
# 402          0.444444     0.424587            0.0            0.0
# 391          0.333333     0.326446            0.0            0.0
# 819          0.555556     0.353306            0.0            0.0
# 1316         0.777778     0.375000            0.0            0.0
#
#       volume_bulk_3  volume_bulk_4  volume_bulk_5  volume_bulk_6  \
# 2253       0.110132       0.412811            0.0            0.0
# 402        0.000000       0.000000            0.0            0.0
# 391        0.000000       0.000000            0.0            0.0
# 819        0.134361       0.000000            0.0            0.0
# 1316       0.215859       0.000000            0.0            0.0
#
#       volume_bulk_7  volume_bulk_9  volume_bulk_10  volume_bulk_11  \
# 2253            0.0            0.0        0.000000             0.0
# ...

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# Рассмотрим модели, построенные по следующим алгоритмам:
# - RandomForestRegressor
# - GradientBoostingRegressor
#
# Подберем гиперпараметры для этих алгоритмов с помощью optuna. Для этого создадим функцию:

# %%
def func_best_params(model, params):
    optuna_cv = OptunaSearchCV(
        model,
        params,
        cv=5,
        scoring='neg_mean_absolute_error',
        n_trials=100,
        n_jobs=-1, 
        verbose=1, 
        random_state=SEED
    )
    optuna_cv.fit(features_train, target_train)
    return optuna_cv

# %% [markdown]
# #### RandomForestRegressor

# %% [markdown]
# Подберем гиперпараметры для RandomForestRegressor:

# %%
#%%time
#  
#params = {
#    "n_estimators": optuna.distributions.IntDistribution(50, 800, log=True),
#    "max_depth": optuna.distributions.IntDistribution(3, 7),
#    "min_samples_split": optuna.distributions.IntDistribution(2, 4),
#    "min_samples_leaf": optuna.distributions.IntDistribution(1, 3)
#}
#  
#rfr = RandomForestRegressor(random_state=SEED)
#
#result = func_best_params(rfr, params)

# %%
#result.study_.best_trial

# %% [markdown]
# Гиперпараметры наилучшей модели:

# %% [markdown]
# *FrozenTrial(number=97, state=TrialState.COMPLETE, values=[-6.100927578790496], datetime_start=datetime.datetime(2023, 3, 13, 15, 44, 59, 577422), datetime_complete=datetime.datetime(2023, 3, 13, 15, 48, 3, 779368), params={'n_estimators': 794, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 3}, user_attrs={'mean_fit_time': 35.56169052124024, 'std_fit_time': 15.818913504784733, 'mean_score_time': 1.1050799369812012, 'std_score_time': 0.7343266755667421, 'split0_test_score': -6.711001149268187, 'split1_test_score': -6.134808734667251, 'split2_test_score': -5.914573684476706, 'split3_test_score': -5.876650662204276, 'split4_test_score': -5.867603663336059, 'mean_test_score': -6.100927578790496, 'std_test_score': 0.32025166756201895}, system_attrs={}, intermediate_values={}, distributions={'n_estimators': IntDistribution(high=800, log=True, low=50, step=1), 'max_depth': IntDistribution(high=7, log=False, low=3, step=1), 'min_samples_split': IntDistribution(high=4, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=3, log=False, low=1, step=1)}, trial_id=97, value=None)*

# %% [markdown]
# #### GradientBoostingRegressor

# %% [markdown]
# Подберем гиперпараметры для GradientBoostingRegressor^

# %%
#%%time
#  
#params = {
#    "learning_rate": optuna.distributions.FloatDistribution(0.00001, 0.01, log=True),
#    "n_estimators": optuna.distributions.IntDistribution(50, 800, log=True),
#    "max_depth": optuna.distributions.IntDistribution(3, 7),
#    "min_samples_split": optuna.distributions.IntDistribution(2, 4),
#    "min_samples_leaf": optuna.distributions.IntDistribution(1, 3),
#    "tol": optuna.distributions.FloatDistribution(0.0001, 0.01, log=True)
#}
#  
#gbr = GradientBoostingRegressor(random_state=SEED)
#
#result = func_best_params(gbr, params)

# %%
#result.study_.best_trial

# %% [markdown]
# Гиперпараметры наилучшей модели:

# %% [markdown]
# *FrozenTrial(number=92, state=TrialState.COMPLETE, values=[-5.958747709809423], datetime_start=datetime.datetime(2023, 3, 13, 16, 18, 0, 375983), datetime_complete=datetime.datetime(2023, 3, 13, 16, 20, 57, 686999), params={'learning_rate': 0.009741674488038424, 'n_estimators': 580, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'tol': 0.006825709542552263}, user_attrs={'mean_fit_time': 35.31984691619873, 'std_fit_time': 0.7647593653556157, 'mean_score_time': 0.04330940246582031, 'std_score_time': 0.03602335952627439, 'split0_test_score': -6.655898532375992, 'split1_test_score': -5.785872884774234, 'split2_test_score': -5.94551540163796, 'split3_test_score': -5.677967784429597, 'split4_test_score': -5.728483945829334, 'mean_test_score': -5.958747709809423, 'std_test_score': 0.3599830096030407}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.01, log=True, low=1e-05, step=None), 'n_estimators': IntDistribution(high=800, log=True, low=50, step=1), 'max_depth': IntDistribution(high=7, log=False, low=3, step=1), 'min_samples_split': IntDistribution(high=4, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=3, log=False, low=1, step=1), 'tol': FloatDistribution(high=0.01, log=True, low=0.0001, step=None)}, trial_id=92, value=None)*

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Для обучения моделей рассмотрим следующие алгоритмы:
# - LinearRegressor
# - RandomForestRegressor
# - GradientBoostingRegressor
# - Полносвязная нейронная сеть

# %% [markdown]
# #### LinearRegression

# %% [markdown]
# Обучим модель, построенную по алгоритму LinearRegression:

# %%
lr_model = LinearRegression()

# %%
# %%time

scores = cross_val_score(
    lr_model, features_train, target_train, cv=5, scoring='neg_mean_absolute_error'
)
scores = abs(scores)
print('Средняя метрика качества модели: %.2f (%.2f)' % (scores.mean(), scores.std()))
# Out:
# Средняя метрика качества модели: 6.36 (0.27)
# CPU times: user 148 ms, sys: 146 ms, total: 294 ms
# Wall time: 244 ms

# %% [markdown]
# Средняя метрика качества модели, построенной по алгоритму LinearRegression - 6.36.

# %% [markdown]
# #### RandomForestRegressor

# %% [markdown]
# Обучим модель, построенную по алгоритму RandomForestRegressor:

# %%
rf_params = {
    'n_estimators': 794, 
    'max_depth': 7, 
    'min_samples_split': 3, 
    'min_samples_leaf': 3
}

rf_model = RandomForestRegressor(
    **rf_params, 
    random_state=SEED,
    n_jobs=-1
)

# %%
# %%time

scores = cross_val_score(
    rf_model, features_train, target_train, cv=5, scoring='neg_mean_absolute_error'
)
scores = abs(scores)
print('Средняя метрика качества модели: %.2f (%.2f)' % (scores.mean(), scores.std()))
# Out:
# Средняя метрика качества модели: 6.12 (0.20)
# CPU times: user 20 s, sys: 87.5 ms, total: 20.1 s
# Wall time: 20.1 s

# %% [markdown]
# Средняя метрика качества модели, построенной по алгоритму RandomForestRegressor - 6.12.

# %% [markdown]
# #### GradientBoostingRegressor

# %% [markdown]
# Обучим модель, построенную по алгоритму GradientBoostingRegressor:

# %%
gb_params = {
    'learning_rate': 0.009741674488038424, 
    'n_estimators': 580, 
    'max_depth': 5, 
    'min_samples_split': 2, 
    'min_samples_leaf': 1, 
    'tol': 0.006825709542552263
}

gb_model = GradientBoostingRegressor(
    **gb_params,
    random_state=SEED
)

# %%
# %%time

scores = cross_val_score(
    gb_model, features_train, target_train, cv=5, scoring='neg_mean_absolute_error'
)
scores = abs(scores)
print('Средняя метрика качества модели: %.2f (%.2f)' % (scores.mean(), scores.std()))
# Out:
# Средняя метрика качества модели: 6.10 (0.24)
# CPU times: user 14.3 s, sys: 9.65 ms, total: 14.3 s
# Wall time: 14.3 s

# %% [markdown]
# Средняя метрика качества модели, построенной по алгоритму GradientBoostingRegressor - 6.10.

# %% [markdown]
# #### Полносвязная нейронная сеть

# %% [markdown]
# Создадим полносвязную нейронную сеть со следующей архитектурой:

# %%
def func_create_model(input_shape):
    optimizer = Adam(learning_rate=0.0001)
    model = Sequential()
    model.add(Dense(input_shape[0], activation='relu', input_shape=input_shape))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(2, activation='relu'))
    model.add(Dense(1, activation='linear'))
    
    model.build()
    model.compile(
        optimizer=optimizer, 
        loss='mse',
        metrics=['mae']
    )
    print(model.summary())
    
    return model

# %% [markdown]
# Посмотрим на получившуюся архитектуру сети:

# %%
nn_model = func_create_model((features_train.shape[1],))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 26)                702
#
#  dense_1 (Dense)             (None, 32)                864
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 2)                 18
#
#  dense_5 (Dense)             (None, 1)                 3
#
# ...
# Total params: 2,251
# Trainable params: 2,251
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2023-03-13 23:13:15.711549: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %% [markdown]
# Установим для сети раннюю остановку, чтобы остановить тренировку, когда функция потерь не улучшается после определенной эпохи:

# %%
callback = EarlyStopping(monitor='loss', patience=5)

# %% [markdown]
# Обучим модель:

# %%
nn_model.fit(
    features_train,
    target_train,
    epochs=1500,
    callbacks=[callback]
)
# Out:
# Epoch 1/1500
# 53/53 [==============================] - 1s 4ms/step - loss: 2538935.2500 - mae: 1593.3658
# Epoch 2/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2538750.0000 - mae: 1593.3076
# Epoch 3/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2538563.5000 - mae: 1593.2493
# Epoch 4/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2538329.0000 - mae: 1593.1757
# Epoch 5/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2538004.5000 - mae: 1593.0736
# Epoch 6/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2537540.5000 - mae: 1592.9283
# Epoch 7/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2536862.0000 - mae: 1592.7157
# Epoch 8/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2535848.7500 - mae: 1592.3970
# Epoch 9/1500
# 53/53 [==============================] - 0s 4ms/step - loss: 2534386.7500 - mae: 1591.9385
# Epoch 10/1500
# ...

# %% [markdown]
# Наилучшая метрика качества МАЕ нейронной сети при наименьшей функции потерь - 6.15.

# %% [markdown]
# ### Вывод

# %% [markdown]
# В рамках данного этапа были:
# - отмасштабированы количественные признаки,
# - проведен подбор гиперпараметров с помощью optuna для алгоритмов RandomForestRegressor, GradientBoostingRegressor, LGBMRegressor,
# - построена полносвязная нейронная сеть,
# - проведено обучение.
#
# По результатам обучения на обучающей выборке лучшей стала модель GradientBoostingRegressor со значением метрики качества MAE, равной 6.10.

# %% [markdown]
# ## Тестирование и анализ результатов

# %% [markdown]
# ### Проверка модели на тестовой выборке

# %% [markdown]
# Проверим наилучшую модель на тестовой выборке:

# %%
best_model = GradientBoostingRegressor(
    **gb_params,
    random_state=SEED
)

best_model.fit(features_train, target_train)
mae = mean_absolute_error(target_test, best_model.predict(features_test))
print('Значение MAE на тестовой выборке для наилучшей модели:', round(mae, 2))
# Out:
# Значение MAE на тестовой выборке для наилучшей модели: 6.01

# %% [markdown]
# ### Анализ важности признаков

# %% [markdown]
# Для анализа важности признаков создадим следующую функцию:

# %%
def func_features_importance(model, column_names):
    feats = {}
    for feature, importance in zip(column_names, model.feature_importances_):
        feats[feature] = importance
    importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-Importance'})
    importances = importances.sort_values(by='Gini-Importance', ascending=False)
    importances = importances.reset_index()
    importances = importances.rename(columns={'index': 'Features'})
    sns.set(font_scale = 5)
    sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
    fig, ax = plt.subplots()
    fig.set_size_inches(12, 12)
    sns.barplot(x=importances['Gini-Importance'], y=importances['Features'], data=importances, color='lightgreen')
    plt.xlabel('Важность', fontsize=15, weight = 'bold')
    plt.ylabel('Признаки', fontsize=15, weight = 'bold')
    plt.title(f'Анализ важности признаков для наилучшей модели', fontsize=15, weight = 'bold')
    display(plt.show())

# %%
func_features_importance(best_model, features_train.columns)
# Out:
# None

# %% [markdown]
# Из полученной визуализации можно сделать вывод, что Топ-3 наиболее важных признаков для полученной модели являются:
# - значение первой измеренной температуры стали,
# - полное значение мощности нагрева электодами,
# - суммарное время нагрева сплава.

# %% [markdown]
# Посмотрим на диаграмму рассеяния целевой переменной и значением первой измеренной температуры:

# %%
color = np.array([.2, .4, .6])
ax = df_steel.plot(
    kind='scatter', y='temperature', x='first_temperature', 
    grid=True, ylim=(1540,1650), xlim=(1500,1700), alpha=0.7, figsize=(12,10), fontsize=12, c=np.atleast_2d(color)
)
ax.set_title('Диаграмма рассеяния', fontsize=16)
ax.set_xlabel('Признак "first_temperature"', fontsize=12)
ax.set_ylabel('Целевой признак "temperature"', fontsize=12)
None

# %% [markdown]
# Исходя из полученной визуализации, зависимость между целевой переменной и значением первой измеренной температуры не описывается простой алгебраической функцией, возможно зависимость эмпирическая.

# %% [markdown]
# ## Вывод

# %% [markdown]
# В рамках данного проекта решалась задача регрессии по прогнозированию температуры стали.
#
# На первом этапе был проведен предварительный анализ данных и были рассчитаны новые показатели: суммарное время нагрева электродами, количество запусков нагрева электродами и среднее соотношение потребления активной и реактивной мощности.
#
# Далее, в рамках этапа предобработки данных был проведен отбор признаков, заполнены пропущенные значения в столбцах,
# измененены типы данных.
#
# На этапе исследовательского анализа данных были проанализированы:
# - линейная и нелинейная корреляция признаков,
# - доля использования сыпучих материалов в партиях,
# - частота добавления проволочных материалов,
# - распределение данных о температуре,
# - распределение числа итераций в партии,
# - распределение продолжительности времени нагрева стали,
# - распределение полной мощности.
#
# Далее был проведен этап разработки наилучшей модели, в рамках которой были:
# - отмасштабированы количественные признаки,
# - проведен подбор гиперпараметров с помощью optuna для алгоритмов RandomForestRegressor, GradientBoostingRegressor, LGBMRegressor,
# - построена полносвязная нейронная сеть,
# - проведено обучение моделей.
#
# По результатам данного этапа на обучающей выборке лучшей стала модель GradientBoostingRegressor.
#
# Далее было проведено тестирование полученной модели - метрика качества МАЕ на тестовой выборке получилась равной 6.01, что удовлетворяет требованиям к проекту.
#
# Кроме того, был проведен анализ важности признаков наилучшей модели, топ-3 из которых:
# - значение первой измеренной температуры стали,
# - полное значение мощности нагрева электодами,
# - суммарное время нагрева сплава.
#
# И в заключении была проанализована зависимость между целевой переменной и наиболее важным признаком - значением первой измеренной температуры, но по результатам анализа установить характер зависимости между величинами не удалось.
